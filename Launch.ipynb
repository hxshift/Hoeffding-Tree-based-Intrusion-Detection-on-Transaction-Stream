# %%
import producer
import consumer
import interface


interface.launch_interface()
# Out:
# Producer ready. Call START_STREAM() to begin, STOP_STREAM() to end.
# Consumer ready. Use START_DETECT() / STOP_DETECT() / STOP_ALL().
